# %% [markdown]
# This implementaion will use LTSM to predict stock prices. Our goal is to predict the price of Nvidia(NVDA) stock prices for the period 25 Oct to 7 Nov, which is exactly 10 days.

# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers

stock_data = pd.read_csv("NVDA.csv")
stock_data.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1252  2023-10-17  440.000000  447.540009  424.799988  439.380005  439.380005
# 1253  2023-10-18  425.910004  432.190002  418.250000  421.959991  421.959991
# 1254  2023-10-19  428.109985  432.970001  418.820007  421.010010  421.010010
# 1255  2023-10-20  418.899994  424.700012  410.779999  413.869995  413.869995
# 1256  2023-10-23  412.290009  432.480011  409.450012  429.750000  429.750000
#
#         Volume
# 1252  81233300
# 1253  62729400
# 1254  50123300
# 1255  47638100
# 1256  47721800

# %%
# check if any row or column contains invalid values
stock_data.isna().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %% [markdown]
# We will try to see the graph of the historical closing prices against time.

# %%
stock_data.loc[:, ['Date', 'Close']]
# Out:
#             Date       Close
# 0     2018-10-24   49.852501
# 1     2018-10-25   51.959999
# 2     2018-10-26   49.572498
# 3     2018-10-29   46.404999
# 4     2018-10-30   50.750000
# ...          ...         ...
# 1252  2023-10-17  439.380005
# 1253  2023-10-18  421.959991
# 1254  2023-10-19  421.010010
# 1255  2023-10-20  413.869995
# 1256  2023-10-23  429.750000
#
# [1257 rows x 2 columns]

# %%
plt.figure(figsize=(15, 8))
plt.title('Stock Prices History')
plt.plot(stock_data.loc[:, 'Date'], stock_data.loc[: , 'Close'])
plt.xticks(np.arange(0,1230,100))
plt.xlabel('Date')
plt.ylabel('Prices ($)')
# Out:
# Text(0, 0.5, 'Prices ($)')

# %% [markdown]
# We will first split the data into training and testing sets. Then attempt to normalise the data to the range of 0 to 1.

# %%
# We set the training set size to be 80% of total dataset
training_data_len = math.ceil(len(stock_data)* 0.8)
training_set = stock_data[['Close']].iloc[:training_data_len].values
test_set = stock_data[['Close']].iloc[training_data_len-12:].values

# Use the MinMaxScaler function to scale the training data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_training_set = scaler.fit_transform(training_set)

# Create a 12-days window of historical prices (i-12) as our feature data
# (x_train) and the following 12-days window as label data (y_train)
X_train = []
y_train = []

for i in range(12, training_data_len):
  X_train.append(scaled_training_set[i-12:i, 0])
  y_train.append(scaled_training_set[i, 0])

# convert array into numpy array
X_train, y_train = np.array(X_train), np.array(y_train)
# reshape X to the format (values, time-steps, 1 dimensional output)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# Now we will start building the model. We will build the LSTM with 100 neurons and 4 hidden layers. Finally, we will assign 1 neuron in the output layer for predicting the normalized stock price. We will use the RMSE loss function and the Adam stochastic gradient descent optimizer.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True,
               input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100))
model.add(Dropout(0.2))
# Adding a dense layer
model.add(layers.Dense(25))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 150, batch_size = 20)
# Out:
# Epoch 1/150
# 50/50 [==============================] - 7s 18ms/step - loss: 0.0168
# Epoch 2/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0035
# Epoch 3/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0030
# Epoch 4/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0031
# Epoch 5/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0026
# Epoch 6/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0026
# Epoch 7/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0035
# Epoch 8/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0028
# Epoch 9/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0024
# Epoch 10/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0025
# Epoch 11/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0023
# Epoch 12/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0023
# Epoch 13/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0026
# Epoch 14/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0020
# Epoch 15/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 16/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0022
# Epoch 17/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 18/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 19/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0020
# Epoch 20/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0017
# Epoch 21/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0016
# Epoch 22/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0016
# Epoch 23/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0016
# Epoch 24/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0015
# Epoch 25/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0018
# Epoch 26/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0015
# Epoch 27/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0016
# Epoch 28/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0015
# Epoch 29/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0012
# Epoch 30/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0013
# Epoch 31/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0023
# Epoch 32/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0012
# Epoch 33/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0013
# Epoch 34/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 35/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0010
# Epoch 36/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 37/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 38/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 39/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0014
# Epoch 40/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0013
# Epoch 41/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 42/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0012
# Epoch 43/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0013
# Epoch 44/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0014
# Epoch 45/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 46/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 47/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0014
# Epoch 48/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 49/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 50/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 51/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 52/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0013
# Epoch 53/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 54/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 55/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.7870e-04
# Epoch 56/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 57/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.9459e-04
# Epoch 58/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 59/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.9028e-04
# Epoch 60/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 61/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0010
# Epoch 62/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0011
# Epoch 63/150
# 50/50 [==============================] - 1s 20ms/step - loss: 9.3783e-04
# Epoch 64/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 65/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 66/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 67/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.3638e-04
# Epoch 68/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0012
# Epoch 69/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 70/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.6996e-04
# Epoch 71/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.5604e-04
# Epoch 72/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 73/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.8516e-04
# Epoch 74/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0013
# Epoch 75/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 76/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.1412e-04
# Epoch 77/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 78/150
# 50/50 [==============================] - 1s 18ms/step - loss: 8.9265e-04
# Epoch 79/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 80/150
# 50/50 [==============================] - 1s 18ms/step - loss: 8.4742e-04
# Epoch 81/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 82/150
# 50/50 [==============================] - 1s 19ms/step - loss: 8.7714e-04
# Epoch 83/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0011
# Epoch 84/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 85/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 86/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 87/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0012
# Epoch 88/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.0927e-04
# Epoch 89/150
# 50/50 [==============================] - 1s 19ms/step - loss: 9.4981e-04
# Epoch 90/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.0667e-04
# Epoch 91/150
# 50/50 [==============================] - 1s 17ms/step - loss: 8.7110e-04
# Epoch 92/150
# 50/50 [==============================] - 1s 17ms/step - loss: 8.8321e-04
# Epoch 93/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 94/150
# 50/50 [==============================] - 1s 19ms/step - loss: 9.9424e-04
# Epoch 95/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 96/150
# 50/50 [==============================] - 1s 19ms/step - loss: 9.1804e-04
# Epoch 97/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.6676e-04
# Epoch 98/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.7000e-04
# Epoch 99/150
# 50/50 [==============================] - 1s 17ms/step - loss: 8.6789e-04
# Epoch 100/150
# 50/50 [==============================] - 1s 19ms/step - loss: 9.3025e-04
# Epoch 101/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.9447e-04
# Epoch 102/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 103/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.4617e-04
# Epoch 104/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.4149e-04
# Epoch 105/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.3382e-04
# Epoch 106/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.6929e-04
# Epoch 107/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.6194e-04
# Epoch 108/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.6238e-04
# Epoch 109/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 110/150
# 50/50 [==============================] - 1s 17ms/step - loss: 8.2964e-04
# Epoch 111/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 112/150
# 50/50 [==============================] - 1s 17ms/step - loss: 8.4782e-04
# Epoch 113/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 114/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 115/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.0867e-04
# Epoch 116/150
# 50/50 [==============================] - 1s 17ms/step - loss: 8.5856e-04
# Epoch 117/150
# 50/50 [==============================] - 1s 18ms/step - loss: 8.1910e-04
# Epoch 118/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.1180e-04
# Epoch 119/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 120/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.5531e-04
# Epoch 121/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 122/150
# 50/50 [==============================] - 1s 19ms/step - loss: 9.6339e-04
# Epoch 123/150
# 50/50 [==============================] - 1s 19ms/step - loss: 9.1549e-04
# Epoch 124/150
# 50/50 [==============================] - 1s 17ms/step - loss: 8.9154e-04
# Epoch 125/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 126/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.8581e-04
# Epoch 127/150
# 50/50 [==============================] - 1s 20ms/step - loss: 8.9409e-04
# Epoch 128/150
# 50/50 [==============================] - 1s 19ms/step - loss: 9.3197e-04
# Epoch 129/150
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 130/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.7830e-04
# Epoch 131/150
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 132/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.4652e-04
# Epoch 133/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0011
# Epoch 134/150
# 50/50 [==============================] - 1s 20ms/step - loss: 7.7685e-04
# Epoch 135/150
# 50/50 [==============================] - 1s 18ms/step - loss: 8.7001e-04
# Epoch 136/150
# 50/50 [==============================] - 1s 18ms/step - loss: 8.5036e-04
# Epoch 137/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.0228e-04
# Epoch 138/150
# 50/50 [==============================] - 1s 18ms/step - loss: 8.7525e-04
# Epoch 139/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.5146e-04
# Epoch 140/150
# 50/50 [==============================] - 1s 17ms/step - loss: 8.4659e-04
# Epoch 141/150
# 50/50 [==============================] - 1s 17ms/step - loss: 8.6254e-04
# Epoch 142/150
# 50/50 [==============================] - 1s 18ms/step - loss: 9.6847e-04
# Epoch 143/150
# 50/50 [==============================] - 1s 18ms/step - loss: 8.3587e-04
# Epoch 144/150
# 50/50 [==============================] - 1s 18ms/step - loss: 7.8162e-04
# Epoch 145/150
# 50/50 [==============================] - 1s 18ms/step - loss: 7.9023e-04
# Epoch 146/150
# 50/50 [==============================] - 1s 17ms/step - loss: 7.5893e-04
# Epoch 147/150
# 50/50 [==============================] - 1s 17ms/step - loss: 7.7528e-04
# Epoch 148/150
# 50/50 [==============================] - 1s 17ms/step - loss: 7.8247e-04
# Epoch 149/150
# 50/50 [==============================] - 1s 17ms/step - loss: 9.6180e-04
# Epoch 150/150
# 50/50 [==============================] - 1s 17ms/step - loss: 7.5669e-04

# %% [markdown]
# Preparing the test set below.

# %%
# test set is the set we split at the start
scaled_test_set = scaler.fit_transform(test_set.reshape(-1, 1))

X_test = []
for i in range(12, len(scaled_test_set)):
    X_test.append(scaled_test_set[i-12:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (251, 12, 1)

# %% [markdown]
# Start predicting with the test set.

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# 8/8 [==============================] - 1s 7ms/step

# %% [markdown]
# Now we shall visualise the result.

# %%
# Visualising the results
plt.plot(stock_data.loc[training_data_len:, 'Date'], test_set[12:, :], color = 'black', label = 'Real NVDA Stock Price')
plt.plot(stock_data.loc[training_data_len:, 'Date'], predicted_stock_price, color = 'red', label = 'Predicted NVDA Stock Price')
plt.xticks(np.arange(0,len(test_set)-12,50))
plt.title('NVDA Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('NVDA Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Evaluation
# We will measure the root mean squared error of the predicted values against the actual values.

# %%
print(predicted_stock_price[:-12])
rmse = np.sqrt(np.mean(predicted_stock_price - test_set[12:, :])**2)
rmse
# Out:
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\HCM\OneDrive - National University of Singapore\Documents\NUS\NUS fintech\ML project 1\Huang_Chao_Ming_Impl_1 copy.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/HCM/OneDrive%20-%20National%20University%20of%20Singapore/Documents/NUS/NUS%20fintech/ML%20project%201/Huang_Chao_Ming_Impl_1%20copy.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> print(predicted_stock_price[:-12])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HCM/OneDrive%20-%20National%20University%20of%20Singapore/Documents/NUS/NUS%20fintech/ML%20project%201/Huang_Chao_Ming_Impl_1%20copy.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> rmse = np.sqrt(np.mean(predicted_stock_price - test_set[12:, :])**2)
#       <a href='vscode-notebook-cell:/c%3A/Users/HCM/OneDrive%20-%20National%20University%20of%20Singapore/Documents/NUS/NUS%20fintech/ML%20project%201/Huang_Chao_Ming_Impl_1%20copy.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> rmse
#
# ValueError: operands could not be broadcast together with shapes (12,1) (251,1)

# %% [markdown]
# ### Actual Prediction
# The trained model seems to be performing reasonably well, so I will start training based on the whole dataset and predict the stock prices for the period 25 Oct to 7 Nov (10 days)
# However, data on 24 Oct cannot be obatined since that will be after the submission deadline. Hence we will train for 12 days period and truncate it to the required 10 days period.

# %%
scaled_data = scaler.fit_transform(stock_data[['Close']].values)

X = []
y = []
for i in range(12, len(scaled_data)):
    X.append(scaled_data[i-12:i, 0])
    y.append(scaled_data[i, 0])
X = np.array(X)
y = np.array(y)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True,
               input_shape = (X.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100))
model.add(Dropout(0.2))
# Adding a dense layer
model.add(layers.Dense(25))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 200, batch_size = 20)
# Out:
# Epoch 1/200
# 50/50 [==============================] - 7s 18ms/step - loss: 0.0193
# Epoch 2/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0032
# Epoch 3/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0036
# Epoch 4/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0034
# Epoch 5/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0026
# Epoch 6/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0031
# Epoch 7/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0029
# Epoch 8/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0027
# Epoch 9/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0025
# Epoch 10/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0033
# Epoch 11/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0028
# Epoch 12/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0022
# Epoch 13/200
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0026
# Epoch 14/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0020
# Epoch 15/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0024
# Epoch 16/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0019
# Epoch 17/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0024
# Epoch 18/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 19/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0017
# Epoch 20/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 21/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0015
# Epoch 22/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0020
# Epoch 23/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0015
# Epoch 24/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 25/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0013
# Epoch 26/200
# 50/50 [==============================] - 1s 23ms/step - loss: 0.0013
# Epoch 27/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0013
# Epoch 28/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0014
# Epoch 29/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0015
# Epoch 30/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0013
# Epoch 31/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0013
# Epoch 32/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0013
# Epoch 33/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 34/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0013
# Epoch 35/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 36/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 37/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0015
# Epoch 38/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 39/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0014
# Epoch 40/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 41/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0013
# Epoch 42/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 43/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.6259e-04
# Epoch 44/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 45/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 46/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 47/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 48/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 49/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0017
# Epoch 50/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0011
# Epoch 51/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 52/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.7076e-04
# Epoch 53/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0013
# Epoch 54/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 55/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 56/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 57/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 58/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 59/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 60/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.8365e-04
# Epoch 61/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 62/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0013
# Epoch 63/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 64/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 65/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 66/200
# 50/50 [==============================] - 1s 19ms/step - loss: 9.7141e-04
# Epoch 67/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.5789e-04
# Epoch 68/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.3323e-04
# Epoch 69/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 70/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0010
# Epoch 71/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 72/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 73/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 74/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 75/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.8170e-04
# Epoch 76/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.8524e-04
# Epoch 77/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.9324e-04
# Epoch 78/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 79/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 80/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.9689e-04
# Epoch 81/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 82/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.5117e-04
# Epoch 83/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.7842e-04
# Epoch 84/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0013
# Epoch 85/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.7200e-04
# Epoch 86/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.7862e-04
# Epoch 87/200
# 50/50 [==============================] - 1s 18ms/step - loss: 7.5892e-04
# Epoch 88/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.3434e-04
# Epoch 89/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.7211e-04
# Epoch 90/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.8276e-04
# Epoch 91/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.1636e-04
# Epoch 92/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 93/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.5390e-04
# Epoch 94/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.8947e-04
# Epoch 95/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.4417e-04
# Epoch 96/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0014
# Epoch 97/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.7421e-04
# Epoch 98/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.2187e-04
# Epoch 99/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 100/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.8388e-04
# Epoch 101/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 102/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.5389e-04
# Epoch 103/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 104/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.0476e-04
# Epoch 105/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.2622e-04
# Epoch 106/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 107/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.0219e-04
# Epoch 108/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.5850e-04
# Epoch 109/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 110/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.0117e-04
# Epoch 111/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 112/200
# 50/50 [==============================] - 1s 17ms/step - loss: 7.9498e-04
# Epoch 113/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.7377e-04
# Epoch 114/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.3209e-04
# Epoch 115/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.8638e-04
# Epoch 116/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.7514e-04
# Epoch 117/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 118/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.5027e-04
# Epoch 119/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.6022e-04
# Epoch 120/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.7579e-04
# Epoch 121/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.0114e-04
# Epoch 122/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 123/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.8870e-04
# Epoch 124/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.4658e-04
# Epoch 125/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.3371e-04
# Epoch 126/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.1609e-04
# Epoch 127/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0010
# Epoch 128/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 129/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.8241e-04
# Epoch 130/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 131/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.9086e-04
# Epoch 132/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 133/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.8603e-04
# Epoch 134/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.1507e-04
# Epoch 135/200
# 50/50 [==============================] - 1s 19ms/step - loss: 9.0744e-04
# Epoch 136/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.4904e-04
# Epoch 137/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.8987e-04
# Epoch 138/200
# 50/50 [==============================] - 1s 19ms/step - loss: 8.3914e-04
# Epoch 139/200
# 50/50 [==============================] - 1s 21ms/step - loss: 8.5780e-04
# Epoch 140/200
# 50/50 [==============================] - 1s 20ms/step - loss: 7.5711e-04
# Epoch 141/200
# 50/50 [==============================] - 1s 19ms/step - loss: 9.8621e-04
# Epoch 142/200
# 50/50 [==============================] - 1s 19ms/step - loss: 7.9159e-04
# Epoch 143/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0011
# Epoch 144/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.4536e-04
# Epoch 145/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.1572e-04
# Epoch 146/200
# 50/50 [==============================] - 1s 19ms/step - loss: 9.2163e-04
# Epoch 147/200
# 50/50 [==============================] - 1s 20ms/step - loss: 8.0107e-04
# Epoch 148/200
# 50/50 [==============================] - 1s 19ms/step - loss: 9.2959e-04
# Epoch 149/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.8751e-04
# Epoch 150/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.0147e-04
# Epoch 151/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.3090e-04
# Epoch 152/200
# 50/50 [==============================] - 1s 19ms/step - loss: 8.0483e-04
# Epoch 153/200
# 50/50 [==============================] - 1s 19ms/step - loss: 9.5456e-04
# Epoch 154/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.0479e-04
# Epoch 155/200
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0012
# Epoch 156/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0010
# Epoch 157/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.1497e-04
# Epoch 158/200
# 50/50 [==============================] - 1s 20ms/step - loss: 8.4038e-04
# Epoch 159/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.2434e-04
# Epoch 160/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.4241e-04
# Epoch 161/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.7266e-04
# Epoch 162/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.6618e-04
# Epoch 163/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.6020e-04
# Epoch 164/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.2430e-04
# Epoch 165/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.0326e-04
# Epoch 166/200
# 50/50 [==============================] - 1s 19ms/step - loss: 7.6964e-04
# Epoch 167/200
# 50/50 [==============================] - 1s 19ms/step - loss: 8.6033e-04
# Epoch 168/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.3235e-04
# Epoch 169/200
# 50/50 [==============================] - 1s 17ms/step - loss: 7.9081e-04
# Epoch 170/200
# 50/50 [==============================] - 1s 18ms/step - loss: 7.9489e-04
# Epoch 171/200
# 50/50 [==============================] - 1s 19ms/step - loss: 7.9410e-04
# Epoch 172/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.3797e-04
# Epoch 173/200
# 50/50 [==============================] - 1s 20ms/step - loss: 7.4489e-04
# Epoch 174/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.9534e-04
# Epoch 175/200
# 50/50 [==============================] - 1s 20ms/step - loss: 8.1389e-04
# Epoch 176/200
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0011
# Epoch 177/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0013
# Epoch 178/200
# 50/50 [==============================] - 1s 19ms/step - loss: 9.0732e-04
# Epoch 179/200
# 50/50 [==============================] - 1s 18ms/step - loss: 8.5702e-04
# Epoch 180/200
# 50/50 [==============================] - 1s 18ms/step - loss: 7.4436e-04
# Epoch 181/200
# 50/50 [==============================] - 1s 19ms/step - loss: 8.4772e-04
# Epoch 182/200
# 50/50 [==============================] - 1s 18ms/step - loss: 7.4439e-04
# Epoch 183/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.3675e-04
# Epoch 184/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.6688e-04
# Epoch 185/200
# 50/50 [==============================] - 1s 17ms/step - loss: 7.6411e-04
# Epoch 186/200
# 50/50 [==============================] - 1s 17ms/step - loss: 7.4489e-04
# Epoch 187/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.0315e-04
# Epoch 188/200
# 50/50 [==============================] - 1s 17ms/step - loss: 7.2665e-04
# Epoch 189/200
# 50/50 [==============================] - 1s 17ms/step - loss: 7.4008e-04
# Epoch 190/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.4353e-04
# Epoch 191/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.2980e-04
# Epoch 192/200
# 50/50 [==============================] - 1s 18ms/step - loss: 9.8287e-04
# Epoch 193/200
# 50/50 [==============================] - 1s 19ms/step - loss: 8.0836e-04
# Epoch 194/200
# 50/50 [==============================] - 1s 18ms/step - loss: 7.6978e-04
# Epoch 195/200
# 50/50 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 196/200
# 50/50 [==============================] - 1s 17ms/step - loss: 9.7259e-04
# Epoch 197/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.7563e-04
# Epoch 198/200
# 50/50 [==============================] - 1s 17ms/step - loss: 8.4241e-04
# Epoch 199/200
# 50/50 [==============================] - 1s 17ms/step - loss: 7.9088e-04
# Epoch 200/200
# 50/50 [==============================] - 1s 18ms/step - loss: 7.2424e-04

# %%
# predict the stock price for the next 12 days
predicted_stock_price = model.predict(X[-12:])  # last 12 days of data
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[451.97702]
#  [461.4485 ]
#  [458.3201 ]
#  [464.015  ]
#  [471.07266]
#  [473.02722]
#  [462.7978 ]
#  [467.63565]
#  [448.41217]
#  [434.82867]
#  [429.299  ]
#  [420.86472]]

# %%
prediction = pd.DataFrame(predicted_stock_price[1:-1], columns=['Close'])
prediction.to_csv('LSTM_prediction.csv')
